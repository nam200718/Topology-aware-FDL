# %% [markdown]
# # Data Partitioning Visualization
# Run this notebook to visualize the Non-IID data distribution among clients. It will generate a heat map showing the hierarchical partitioning used in Phase 2 experiments (5 clusters, 6 clients each).

# %%
# !git clone https://github.com/nam200718/Topology-aware-FDL.git project_repo
# %cd project_repo
# !pip install -r requirements.txt
# !pip install networkx pytest matplotlib seaborn

# %% [markdown]
# ## Generate Partition Heatmaps

# %%
import os
os.makedirs('outputs/idea1_partitioner', exist_ok=True)
# !python temp/run_partition_demo.py --sweep

# %% [markdown]
# ## Display the generated plots

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import glob

images = glob.glob('outputs/idea1_partitioner/*.png')
for img_path in images:
    plt.figure(figsize=(10, 8))
    img = mpimg.imread(img_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## Package Outputs

# %%
import shutil
from IPython.display import FileLink, display
shutil.make_archive('partitioning_outputs', 'zip', 'outputs/idea1_partitioner')
display(FileLink('partitioning_outputs.zip'))

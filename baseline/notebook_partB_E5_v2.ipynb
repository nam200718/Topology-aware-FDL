# %% [markdown]
# # Experiment 5 (v2): Byzantine Defense on Hierarchical Partition (β = 0.1, x = 1.0)
# Testing Star, Ring, and Hierarchical Ensemble (HE) with Soft Cosine Defense under label_flip and sign_flip attacks with rates [0.0, 0.1, 0.2, 0.3].

# %%
# !git clone https://github.com/nam200718/Topology-aware-FDL.git project_repo
# %cd project_repo
# !pip install -r requirements.txt
# !pip install networkx pytest

# %% [markdown]
# ## Run Experiment 5 (50 rounds, batch_size=128)

# %%
# !python temp/run_baseline_comparison.py --config temp/exp5_defense_hier.yaml

# %% [markdown]
# ## Display Summary (CSV)

# %%
import os, pandas as pd
from IPython.display import display
summary_path = './outputs/exp5_defense_hier/comparison_summary.csv'
if os.path.exists(summary_path):
    df = pd.read_csv(summary_path)
    display(df)

# %% [markdown]
# ## Package & Download Outputs

# %%
import shutil
from IPython.display import FileLink, display
shutil.make_archive('partB_E5_outputs_v2', 'zip', './outputs/exp5_defense_hier')
display(FileLink('partB_E5_outputs_v2.zip'))
